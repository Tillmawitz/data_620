# %% [markdown]
# # Week Two - Assignment Hello Graph World
#
# ## Matthew Tillmawitz

# %% [markdown]
# A simple definition of the Krackhardt kite to ensure proper environment setup.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
krackhardt_dict = {"Andre": ["Carol", "Fernando", "Diane", "Beverly"],
                   "Carol": ["Diane", "Fernando"],
                   "Fernando": ["Garth", "Heather", "Diane"],
                   "Diane": ["Garth", "Ed", "Beverly"],
                   "Beverly": ["Garth", "Ed"],
                   "Ed": ["Garth"],
                   "Garth": ["Heather"],
                   "Heather": ["Ike"],
                   "Ike": ["Jane"]}
G = nx.Graph(krackhardt_dict)

# %%
nx.draw(G, with_labels=True)
plt.show()
